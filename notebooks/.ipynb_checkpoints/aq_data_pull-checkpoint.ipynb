# %%
import pandas as pd
import requests
import time
from datetime import datetime
import pytz
import matplotlib

# %%
avg_over = '1T'

# %%
st_date = '2022-02-23T16:00:00'
en_date = datetime.now().strftime('%Y-%m-%dT%H:%M:%S')

# %%
st_date_utc = datetime.strptime(st_date, '%Y-%m-%dT%H:%M:%S').astimezone(pytz.UTC).strftime('%Y-%m-%dT%H:%M:%SZ')
en_date_utc = datetime.strptime(en_date, '%Y-%m-%dT%H:%M:%S').astimezone(pytz.UTC).strftime('%Y-%m-%dT%H:%M:%SZ')

# %%
print(st_date_utc)
print(en_date_utc)
# Out:
# 2022-02-23T21:00:00Z
# 2022-02-25T23:17:46Z

# %%
# Import and format Praxis data
uri = 'https://aws.southcoastscience.com/topicMessages?topic=nyu/brooklyn/loc/3/particulates&startTime=%s&endTime=%s' \
% (st_date_utc, en_date_utc)
header = {"authorization": "api-key nyu-brooklyn"}
response = requests.get(uri, headers=header)
json = response.json()
data = {}

data['ts'] = pd.to_datetime([ele['rec'] for ele in json['Items']]).tz_convert(tz='US/Eastern')

data['praxis_pm1_vals'] = [ele['val']['pm1'] for ele in json['Items']]
data['praxis_pm2p5_vals'] = [ele['val']['pm2p5'] for ele in json['Items']]
data['praxis_pm10_vals'] = [ele['val']['pm10'] for ele in json['Items']]

data['praxis_pm1_vals_adj'] = [ele['exg']['rn20']['pm1'] for ele in json['Items']]
data['praxis_pm2p5_vals_adj'] = [ele['exg']['rn20']['pm2p5'] for ele in json['Items']]
data['praxis_pm10_vals_adj'] = [ele['exg']['rn20']['pm10'] for ele in json['Items']]

praxis_df = pd.DataFrame(data).set_index('ts').resample(avg_over).mean()

# %%
praxis_df
# Out:
#                            praxis_pm1_vals  praxis_pm2p5_vals  \
# ts
# 2022-02-23 16:00:00-05:00         1.233333           4.583333
# 2022-02-23 16:01:00-05:00         1.066667           4.466667
# 2022-02-23 16:02:00-05:00         1.183333           4.400000
# 2022-02-23 16:03:00-05:00         1.133333           4.000000
# 2022-02-23 16:04:00-05:00         1.100000           3.933333
# ...                                    ...                ...
# 2022-02-23 18:42:00-05:00         0.750000           1.450000
# 2022-02-23 18:43:00-05:00         0.750000           1.666667
# 2022-02-23 18:44:00-05:00         0.833333           1.666667
# 2022-02-23 18:45:00-05:00         0.783333           1.366667
# 2022-02-23 18:46:00-05:00         0.725000           1.625000
#
#                            praxis_pm10_vals  praxis_pm1_vals_adj  \
# ts
# 2022-02-23 16:00:00-05:00         18.583333             5.433333
# 2022-02-23 16:01:00-05:00         18.300000             3.633333
# 2022-02-23 16:02:00-05:00         19.083333             4.533333
# 2022-02-23 16:03:00-05:00         15.000000             4.050000
# 2022-02-23 16:04:00-05:00         12.016667             4.266667
# ...                                     ...                  ...
# 2022-02-23 18:42:00-05:00          2.233333             3.883333
# 2022-02-23 18:43:00-05:00          5.183333             3.716667
# 2022-02-23 18:44:00-05:00          3.716667             3.716667
# 2022-02-23 18:45:00-05:00          3.783333             3.433333
# 2022-02-23 18:46:00-05:00          2.925000             3.900000
#
#                            praxis_pm2p5_vals_adj  praxis_pm10_vals_adj
# ts
# 2022-02-23 16:00:00-05:00               8.666667             26.866667
# 2022-02-23 16:01:00-05:00               7.633333             27.266667
# 2022-02-23 16:02:00-05:00               8.450000             35.500000
# 2022-02-23 16:03:00-05:00               7.300000             30.083333
# 2022-02-23 16:04:00-05:00               7.950000             23.533333
# ...                                          ...                   ...
# 2022-02-23 18:42:00-05:00               4.900000              8.600000
# 2022-02-23 18:43:00-05:00               5.066667             13.366667
# 2022-02-23 18:44:00-05:00               4.550000             10.450000
# 2022-02-23 18:45:00-05:00               3.950000              8.383333
# 2022-02-23 18:46:00-05:00               5.350000             13.675000
#
# [167 rows x 6 columns]

# %%
# Import and format Piera Canary data
# 168
canary_df = pd.DataFrame([])
for x in range(10):
    uri = 'https://sensei.pierasystems.com/api/get-minute-averages/318?page=%i' % x
    response = requests.get(uri)
    json = response.json()
    data = {}
    data['ts'] = pd.to_datetime([ele['time'] for ele in json['data']]).tz_convert(tz='US/Eastern')
    
    data['canary_pm1_vals'] = [ele['pm10'] for ele in json['data']]
    data['canary_pm2p5_vals'] = [ele['pm25'] for ele in json['data']]
    data['canary_pm10_vals'] = [ele['pm100'] for ele in json['data']]
    
    canary_df = pd.concat([canary_df, pd.DataFrame(data)])
    
    time.sleep(0.5)
canary_df = canary_df.set_index('ts').resample(avg_over).mean()

# %%
comb_df = canary_df.join(praxis_df)

# %%
comb_df.plot();

# %%
comb_df
# Out:
#                            canary_pm1_vals  canary_pm2p5_vals  \
# ts
# 2022-02-24 02:10:00-05:00         0.154168           0.180288
# 2022-02-24 02:11:00-05:00         0.089282           0.102342
# 2022-02-24 02:12:00-05:00         0.122937           0.135997
# 2022-02-24 02:13:00-05:00         0.140861           0.153921
# 2022-02-24 02:14:00-05:00         0.162518           0.214758
# ...                                    ...                ...
# 2022-02-25 18:12:00-05:00         0.286655           0.508675
# 2022-02-25 18:13:00-05:00         0.283199           0.492159
# 2022-02-25 18:14:00-05:00         0.270391           0.427111
# 2022-02-25 18:15:00-05:00         0.271732           0.441512
# 2022-02-25 18:16:00-05:00         0.290833           0.421433
#
#                            canary_pm10_vals  praxis_pm1_vals  \
# ts
# 2022-02-24 02:10:00-05:00          0.180288              NaN
# 2022-02-24 02:11:00-05:00          0.102342              NaN
# 2022-02-24 02:12:00-05:00          0.135997              NaN
# 2022-02-24 02:13:00-05:00          0.153921              NaN
# 2022-02-24 02:14:00-05:00          0.214758              NaN
# ...                                     ...              ...
# 2022-02-25 18:12:00-05:00          0.613075              NaN
# 2022-02-25 18:13:00-05:00          0.492159              NaN
# 2022-02-25 18:14:00-05:00          0.427111              NaN
# 2022-02-25 18:15:00-05:00          0.441512              NaN
# 2022-02-25 18:16:00-05:00          0.421433              NaN
#
#                            praxis_pm2p5_vals  praxis_pm10_vals  \
# ts
# 2022-02-24 02:10:00-05:00                NaN               NaN
# 2022-02-24 02:11:00-05:00                NaN               NaN
# 2022-02-24 02:12:00-05:00                NaN               NaN
# 2022-02-24 02:13:00-05:00                NaN               NaN
# 2022-02-24 02:14:00-05:00                NaN               NaN
# ...                                      ...               ...
# 2022-02-25 18:12:00-05:00                NaN               NaN
# 2022-02-25 18:13:00-05:00                NaN               NaN
# 2022-02-25 18:14:00-05:00                NaN               NaN
# 2022-02-25 18:15:00-05:00                NaN               NaN
# 2022-02-25 18:16:00-05:00                NaN               NaN
#
#                            praxis_pm1_vals_adj  praxis_pm2p5_vals_adj  \
# ts
# 2022-02-24 02:10:00-05:00                  NaN                    NaN
# 2022-02-24 02:11:00-05:00                  NaN                    NaN
# 2022-02-24 02:12:00-05:00                  NaN                    NaN
# 2022-02-24 02:13:00-05:00                  NaN                    NaN
# 2022-02-24 02:14:00-05:00                  NaN                    NaN
# ...                                        ...                    ...
# 2022-02-25 18:12:00-05:00                  NaN                    NaN
# 2022-02-25 18:13:00-05:00                  NaN                    NaN
# 2022-02-25 18:14:00-05:00                  NaN                    NaN
# 2022-02-25 18:15:00-05:00                  NaN                    NaN
# 2022-02-25 18:16:00-05:00                  NaN                    NaN
#
#                            praxis_pm10_vals_adj
# ts
# 2022-02-24 02:10:00-05:00                   NaN
# 2022-02-24 02:11:00-05:00                   NaN
# 2022-02-24 02:12:00-05:00                   NaN
# 2022-02-24 02:13:00-05:00                   NaN
# 2022-02-24 02:14:00-05:00                   NaN
# ...                                         ...
# 2022-02-25 18:12:00-05:00                   NaN
# 2022-02-25 18:13:00-05:00                   NaN
# 2022-02-25 18:14:00-05:00                   NaN
# 2022-02-25 18:15:00-05:00                   NaN
# 2022-02-25 18:16:00-05:00                   NaN
#
# [2407 rows x 9 columns]
